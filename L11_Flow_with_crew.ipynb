# %%
from crewai.flow.flow import Flow, listen, start
from pydantic import BaseModel, Field
from typing import List, Dict, Optional
from IPython.display import display
from crewai import Agent, Task, Crew

def log(msg: str) -> None:
    """Show message in Jupyter output (works inside CrewAI flow steps)."""
    display(msg)

llm = "gpt-4o-mini"

# %%
# Define your state model
class UserPreferences(BaseModel):
    theme: str = "light"
    language: str = "English"
    __private_field: str = "This is a private field"

class AppState(BaseModel):
    user_name: str = ""
    preferences: UserPreferences = UserPreferences()
    items: List[str] = []
    topic: str = ""
    processed: bool = False
    completion_percentage: float = 0.0

# %%
# Create a flow with typed state
class StructuredStateFlow(Flow[AppState]):
    def agent_func(self, topic: str):
        """Create the blog agent (must take self so topic receives the string)."""
        general_agent = Agent(
            role="Content blogger",
            goal=f"Plan a blog content on {topic}",
            backstory=(
                "You're working on a blog article about the topic: {topic}. "
                "You collect information that helps the audience learn something "
                "and make informed decisions. Your work is the basis for "
                "the Content Writer to write an article on this topic."
            ).format(topic=topic),
            allow_delegation=False,
            llm=llm,
            verbose=True,
        )
        return general_agent

    @start()
    def initialize_data(self):
        print("Initializing flow data")
        # Set state values (type-checked)
        self.state.user_name = "Ali Khan"
        self.state.preferences.theme = "White"
        self.state.topic = "Ai Agents"
        self.state.preferences.__private_field = " private field written again "

        summary = f"User {self.state.user_name} has {len(self.state.items)} items "
        summary += f"with {self.state.preferences.theme} theme. "
        summary += f"Private field: {self.state.preferences.__private_field} "
        summary += "Data is processed. " if self.state.processed else "Data is not processed. "
        summary += f"Completion: {self.state.completion_percentage}%\n\n"

        # Agent alone has no kickoff(); use Task + Crew, then crew.kickoff()
        agent = self.agent_func(self.state.topic)
        plan_task = Task(
            description=f"Plan a short blog post outline for the topic: {self.state.topic}. "
            "List 3–5 main sections or bullet points.",
            agent=agent,
            expected_output="A brief structured outline (sections or bullet points).",
        )
        crew = Crew(agents=[agent], tasks=[plan_task], verbose=True)
        crew_result = crew.kickoff()
        summary += f"Crew output:\n{crew_result}"
        return summary

# %%
# Run the flow
flow = StructuredStateFlow()
result = await flow.kickoff_async()
print(f"Final result: {result}")
print(f"Final state: {flow.state}")
# Out:
# Flow started with ID: 79777849-7c1d-4bf0-9501-bcb694bdb62e
# Flow started with ID: 79777849-7c1d-4bf0-9501-bcb694bdb62e
# ╭──────────────────────────────────────────────── Flow Execution ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: StructuredStateFlow                                                                                      │
# │  ID: 79777849-7c1d-4bf0-9501-bcb694bdb62e                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# ...
