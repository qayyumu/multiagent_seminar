# %%
# install the necessary libraries 
#!pip install crewai crewai_tools openai 
# langchain_community langchain_openai
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
# choose_LLM = 0
# colab_exp = 0
# import os

llm = "ollama/llama3.2"

# %%
from crewai import Agent, Task, Crew
 
general_agent = Agent(
    role="Content blogger",
    goal="Plan a blog content on {topic}",
    backstory="You're working on a blog article "
              "about the topic: {topic}."
              "You collect information that helps the "
              "audience learn something "
              "and make informed decisions. "
              "Your work is the basis for "
              "the Content Writer to write an article on this topic.",
    allow_delegation=False,
    llm= llm,
	verbose=True
)

# %%
general_agent.kickoff("Multiagent Intelligence")
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── LiteAgent Started ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LiteAgent Session Started                                                                                      │
# │  Name: Content blogger                                                                                          │
# │  id: ddf2b372-9094-48f8-8cef-280a564bac7d                                                                       │
# │  role: Content blogger                                                                                          │
# │  goal: Plan a blog content on {topic}                                                                           │
# │  backstory: You're working on a blog article about the topic: {topic}.You collect information that helps the    │
# │  audience learn something and make informed decisions. Your work is the basis for the Content Writer to write   │
# │  an article on this topic.                                                                                      │
# │  tools: []                                                                                                      │
# │  verbose: True                                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content blogger                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Multiagent Systems (MAS) is a subfield of artificial intelligence that focuses on the study and development    │
# │  of systems composed of multiple interacting agents. These agents are autonomous entities that act              │
# │  independently, making decisions based on their own objectives and rules.                                       │
# │                                                                                                                 │
# │  In MAS, each agent has its own goals, beliefs, and actions, which interact with other agents to achieve        │
# │  complex tasks. The key characteristics of multiagent intelligence include:                                     │
# │                                                                                                                 │
# │  1. **Autonomy**: Each agent acts independently, making decisions without the need for centralized control.     │
# │  2. **Interconnectedness**: Agents interact with each other, sharing information and coordinating their         │
# │  actions.                                                                                                       │
# │  3. **Complexity**: Multiagent systems often exhibit emergent behavior, arising from the interactions between   │
# │  individual agents.                                                                                             │
# │                                                                                                                 │
# │  Applications of multiagent intelligence include:                                                               │
# │                                                                                                                 │
# │  1. **Robotics**: MAS is used in robotic swarms, where multiple robots work together to achieve complex tasks.  │
# │  2. **Networked Systems**: MAS is applied in networked systems, such as sensor networks and autonomous          │
# │  vehicles.                                                                                                      │
# │  3. **E-commerce**: MAS is used in online marketplaces, where multiple agents (e.g., buyers, sellers) interact  │
# │  to achieve their goals.                                                                                        │
# │                                                                                                                 │
# │  Techniques used in multiagent intelligence include:                                                            │
# │                                                                                                                 │
# │  1. **Game Theory**: Used to model the interactions between agents and make decisions that maximize individual  │
# │  payoffs.                                                                                                       │
# │  2. **Machine Learning**: Applied to learn from data and improve agent performance.                             │
# │  3. **Graph Theory**: Used to represent and analyze complex interactions between agents.                        │
# │                                                                                                                 │
# │  Challenges in multiagent intelligence include:                                                                 │
# │                                                                                                                 │
# │  1. **Scalability**: As the number of agents increases, complexity and coordination become significant          │
# │  challenges.                                                                                                    │
# │  2. **Trust**: Agents may have different trust levels or not be trustworthy at all, leading to difficulties in  │
# │  coordination.                                                                                                  │
# │  3. **Communication**: Effective communication is crucial between agents, but it can be challenging due to      │
# │  differences in language, format, or even attention.                                                            │
# │                                                                                                                 │
# │  To overcome these challenges, researchers and practitioners employ various strategies, such as:                │
# │                                                                                                                 │
# │  1. **Federated Learning**: Agents learn from each other's data, promoting cooperation and knowledge sharing.   │
# │  2. **Reinforcement Learning**: Agents learn through trial and error, adapting to their environment and         │
# │  interactions with other agents.                                                                                │
# │  3. **Graph-Based Methods**: Graphs are used to represent complex interactions between agents, facilitating     │
# │  analysis and coordination.                                                                                     │
# │                                                                                                                 │
# │  In conclusion, multiagent intelligence is a rapidly evolving field that seeks to understand and develop        │
# │  systems composed of multiple interacting agents. By leveraging game theory, machine learning, and graph        │
# │  theory, researchers can create more sophisticated and efficient multiagent systems, with applications in       │
# │  various domains, including robotics, networked systems, and e-commerce.                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# LiteAgentOutput(raw="Multiagent Systems (MAS) is a subfield of artificial intelligence that focuses on the study and development of systems composed of multiple interacting agents. These agents are autonomous entities that act independently, making decisions based on their own objectives and rules.\n\nIn MAS, each agent has its own goals, beliefs, and actions, which interact with other agents to achieve complex tasks. The key characteristics of multiagent intelligence include:\n\n1. **Autonomy**: Each agent acts independently, making decisions without the need for centralized control.\n2. **Interconnectedness**: Agents interact with each other, sharing information and coordinating their actions.\n3. **Complexity**: Multiagent systems often exhibit emergent behavior, arising from the interactions between individual agents.\n\nApplications of multiagent intelligence include:\n\n1. **Robotics**: MAS is used in robotic swarms, where multiple robots work together to achieve complex tasks.\n2. **Networked Systems**: MAS is applied in networked systems, such as sensor networks and autonomous vehicles.\n3. **E-commerce**: MAS is used in online marketplaces, where multiple agents (e.g., buyers, sellers) interact to achieve their goals.\n\nTechniques used in multiagent intelligence include:\n\n1. **Game Theory**: Used to model the interactions between agents and make decisions that maximize individual payoffs.\n2. **Machine Learning**: Applied to learn from data and improve agent performance.\n3. **Graph Theory**: Used to represent and analyze complex interactions between agents.\n\nChallenges in multiagent intelligence include:\n\n1. **Scalability**: As the number of agents increases, complexity and coordination become significant challenges.\n2. **Trust**: Agents may have different trust levels or not be trustworthy at all, leading to difficulties in coordination.\n3. **Communication**: Effective communication is crucial between agents, but it can be challenging due to differences in language, format, or even attention.\n\nTo overcome these challenges, researchers and practitioners employ various strategies, such as:\n\n1. **Federated Learning**: Agents learn from each other's data, promoting cooperation and knowledge sharing.\n2. **Reinforcement Learning**: Agents learn through trial and error, adapting to their environment and interactions with other agents.\n3. **Graph-Based Methods**: Graphs are used to represent complex interactions between agents, facilitating analysis and coordination.\n\nIn conclusion, multiagent intelligence is a rapidly evolving field that seeks to understand and develop systems composed of multiple interacting agents. By leveraging game theory, machine learning, and graph theory, researchers can create more sophisticated and efficient multiagent systems, with applications in various domains, including robotics, networked systems, and e-commerce.", pydantic=None, agent_role='Content blogger', usage_metrics={'total_tokens': 0, 'prompt_tokens': 0, 'cached_prompt_tokens': 0, 'completion_tokens': 0, 'successful_requests': 0}, messages=[{'role': 'system', 'content': "You are Content blogger. You're working on a blog article about the topic: {topic}.You collect information that helps the audience learn something and make informed decisions. Your work is the basis for the Content Writer to write an article on this topic.\nYour personal goal is: Plan a blog content on {topic}\n\nTo give my best complete final answer to the task respond using the exact following format:\n\nThought: I now can give a great answer\nFinal Answer: Your final answer must be the great and the most complete as possible, it must be outcome described.\n\nI MUST use these formats, my job depends on it!"}, {'role': 'user', 'content': 'Multiagent Intelligence'}, {'role': 'assistant', 'content': "Thought: I now can give a great answer\n\nFinal Answer: Multiagent Systems (MAS) is a subfield of artificial intelligence that focuses on the study and d ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── LiteAgent Completion ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LiteAgent Completed                                                                                            │
# │  Name: Content blogger                                                                                          │
# │  id: ddf2b372-9094-48f8-8cef-280a564bac7d                                                                       │
# │  role: Content blogger                                                                                          │
# │  goal: Plan a blog content on {topic}                                                                           │
# │  backstory: You're working on a blog article about the topic: {topic}.You collect information that helps the    │
# │  audience learn something and make informed decisions. Your work is the basis for the Content Writer to write   │
# │  an article on this topic.                                                                                      │
# │  tools: []                                                                                                      │
# │  verbose: True                                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# Task
plan_task = Task(
    description=(
        "1. Prioritize the latest trends, key players, "
            "and noteworthy news on {topic}.\n"
        "2. Identify the target audience, considering "
            "their interests and pain points.\n"
        "3. Develop a detailed content outline including "
            "an introduction, key points, and a call to action.\n"
        "4. Include SEO keywords and relevant data or sources."
    ),
    expected_output="A comprehensive content plan document "
        "with an outline, audience analysis, "
        "SEO keywords, and resources.",
    agent=general_agent,
)

# %%
crew = Crew(agents=[general_agent], tasks=[plan_task],verbose=0)
result = crew.kickoff(inputs={"topic": "Multiagent Intelligence"})

print(result)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content blogger                                                                                         │
# │                                                                                                                 │
# │  Task: 1. Prioritize the latest trends, key players, and noteworthy news on Multiagent Intelligence.            │
# │  2. Identify the target audience, considering their interests and pain points.                                  │
# │  3. Develop a detailed content outline including an introduction, key points, and a call to action.             │
# │  4. Include SEO keywords and relevant data or sources.                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content blogger                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Comprehensive Content Plan for Multiagent Intelligence Blog Article                                            │
# │                                                                                                                 │
# │  I. Introduction                                                                                                │
# │  A. Hook: "Unlocking the Power of Cooperative Problem-Solving with Multiagent Intelligence"                     │
# │  B. Brief overview of multiagent intelligence and its increasing importance in AI research                      │
# │  C. Thesis statement: In this article, we will delve into the world of multiagent intelligence, exploring its   │
# │  latest trends, key players, and applications.                                                                  │
# │                                                                                                                 │
# │  II. Audience Analysis                                                                                          │
# │  A. Target audience:                                                                                            │
# │          * Professionals in AI and machine learning                                                             │
# │          * Researchers interested in multiagent systems                                                         │
# │          * Students and educators looking to learn about advanced AI topics                                     │
# │  B. Interests and pain points:                                                                                  │
# │          * Understanding the basics of multiagent intelligence                                                  │
# │          * Learning how to apply multiagent models to real-world problems                                       │
# │          * Staying up-to-date with the latest developments in the field                                         │
# │                                                                                                                 │
# │  III. Latest Trends in Multiagent Intelligence                                                                  │
# │  A. Agent-based modeling and simulation                                                                         │
# │  B. Explainable AI (XAI) for multiagent systems                                                                 │
# │  C. Multiagent reinforcement learning (MARL)                                                                    │
# │  D. Cognitive architectures for multiagent decision-making                                                      │
# │                                                                                                                 │
# │  IV. Key Players in Multiagent Intelligence                                                                     │
# │  A. Researchers:                                                                                                │
# │          * Jason Mathewson (University of Pennsylvania)                                                         │
# │          * Peter Stone (University of Texas at Austin)                                                          │
# │          * Eric Horvitz (Microsoft Research)                                                                    │
# │  B. Organizations:                                                                                              │
# │          * MIT CSAIL's Multiagent Systems Group                                                                 │
# │          * University of Edinburgh's Intelligent Systems Laboratory                                             │
# │                                                                                                                 │
# │  V. Noteworthy News and Developments                                                                            │
# │  A. Recent breakthroughs in multiagent reinforcement learning                                                   │
# │  B. Advances in explainable AI for multiagent systems                                                           │
# │  C. Applications of multiagent intelligence in industries such as healthcare and finance                        │
# │                                                                                                                 │
# │  VI. Content Outline                                                                                            │
# │  I. Introduction                                                                                                │
# │  II. The Basics of Multiagent Intelligence                                                                      │
# │  III. Trends and Applications                                                                                   │
# │  IV. Key Players and Organizations                                                                              │
# │  V. Noteworthy News and Developments                                                                            │
# │  VI. Conclusion                                                                                                 │
# │  VII. Call to Action: Getting Started with Multiagent Intelligence Research                                     │
# │                                                                                                                 │
# │  VIII. SEO Keywords                                                                                             │
# │  A. Multiagent intelligence                                                                                     │
# │  B. Artificial intelligence (AI)                                                                                │
# │  C. Machine learning (ML)                                                                                       │
# │  D. Cooperative problem-solving                                                                                 │
# │  E. Explainable AI (XAI)                                                                                        │
# │                                                                                                                 │
# │  IX. Resources                                                                                                  │
# │  A. Books:                                                                                                      │
# │          * "Multiagent Systems" by Eric Horvitz and Michael Wellman                                             │
# │          * "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig                      │
# │  B. Research papers:                                                                                            │
# │          * "Deep Reinforcement Learning with Double Q-Learning" (Arabsat et al., 2020)                          │
# │          * "Explaining Multiagent Systems using Explanable AI" (Lee et al., 2019)                               │
# │                                                                                                                 │
# │  X. Conclusion                                                                                                  │
# │                                                                                                                 │
# │  Note: This content plan is a comprehensive guide to creating a blog article on multiagent intelligence. The    │
# │  outline, audience analysis, SEO keywords, and resources provided will help ensure that the final article is    │
# │  informative, engaging, and optimized for search engines.                                                       │
# │                                                                                                                 │
# │  Resources:                                                                                                     │
# │  1.https://www.nature.com/articles/s41595-019-4649-y                                                            │
# │  2.http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.732.2245&rep=rep1&type=pdf                          │
# │  3.http://ai.stanford.edu/~amirreza/ams.pdf                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Comprehensive Content Plan for Multiagent Intelligence Blog Article
#
# I. Introduction
# A. Hook: "Unlocking the Power of Cooperative Problem-Solving with Multiagent Intelligence"
# B. Brief overview of multiagent intelligence and its increasing importance in AI research
# C. Thesis statement: In this article, we will delve into the world of multiagent intelligence, exploring its latest trends, key players, and applications.
#
# II. Audience Analysis
# A. Target audience:
# 	* Professionals in AI and machine learning
# 	* Researchers interested in multiagent systems
# 	* Students and educators looking to learn about advanced AI topics
# B. Interests and pain points:
# 	* Understanding the basics of multiagent intelligence
# 	* Learning how to apply multiagent models to real-world problems
# 	* Staying up-to-date with the latest developments in the field
#
# III. Latest Trends in Multiagent Intelligence
# A. Agent-based modeling and simulation
# B. Explainable AI (XAI) for multiagent systems
# C. Multiagent reinforcement learning (MARL)
# D. Cognitive architectures for multiagent decision-making
#
# IV. Key Players in Multiagent Intelligence
# A. Researchers:
# 	* Jason Mathewson (University of Pennsylvania)
# 	* Peter Stone (University of Texas at Austin)
# 	* Eric Horvitz (Microsoft Research)
# B. Organizations:
# 	* MIT CSAIL's Multiagent Systems Group
# 	* University of Edinburgh's Intelligent Systems Laboratory
#
# V. Noteworthy News and Developments
# A. Recent breakthroughs in multiagent reinforcement learning
# B. Advances in explainable AI for multiagent systems
# C. Applications of multiagent intelligence in industries such as healthcare and finance
#
# VI. Content Outline
# I. Introduction
# II. The Basics of Multiagent Intelligence
# III. Trends and Applications
# IV. Key Players and Organizations
# V. Noteworthy News and Developments
# VI. Conclusion
# VII. Call to Action: Getting Started with Multiagent Intelligence Research
#
# VIII. SEO Keywords
# A. Multiagent intelligence
# B. Artificial intelligence (AI)
# C. Machine learning (ML)
# D. Cooperative problem-solving
# E. Explainable AI (XAI)
#
# IX. Resources
# A. Books:
# 	* "Multiagent Systems" by Eric Horvitz and Michael Wellman
# 	* "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig
# B. Research papers:
# 	* "Deep Reinforcement Learning with Double Q-Learning" (Arabsat et al., 2020)
# 	* "Explaining Multiagent Systems using Explanable AI" (Lee et al., 2019)
#
# X. Conclusion
#
# Note: This content plan is a comprehensive guide to creating a blog article on multiagent intelligence. The outline, audience analysis, SEO keywords, and resources provided will help ensure that the final article is informative, engaging, and optimized for search engines.
#
# Resources:
# 1.https://www.nature.com/articles/s41595-019-4649-y
# 2.http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.732.2245&rep=rep1&type=pdf
# 3.http://ai.stanford.edu/~amirreza/ams.pdf

# %%
from IPython.display import display, Markdown, display_png

display(Markdown(result.raw))
# Out:
# Comprehensive Content Plan for Multiagent Intelligence Blog Article
#
# I. Introduction
# A. Hook: "Unlocking the Power of Cooperative Problem-Solving with Multiagent Intelligence"
# B. Brief overview of multiagent intelligence and its increasing importance in AI research
# C. Thesis statement: In this article, we will delve into the world of multiagent intelligence, exploring its latest trends, key players, and applications.
#
# II. Audience Analysis
# A. Target audience:
# 	* Professionals in AI and machine learning
# 	* Researchers interested in multiagent systems
# 	* Students and educators looking to learn about advanced AI topics
# B. Interests and pain points:
# 	* Understanding the basics of multiagent intelligence
# 	* Learning how to apply multiagent models to real-world problems
# 	* Staying up-to-date with the latest developments in the field
#
# III. Latest Trends in Multiagent Intelligence
# A. Agent-based modeling and simulation
# B. Explainable AI (XAI) for multiagent systems
# C. Multiagent reinforcement learning (MARL)
# D. Cognitive architectures for multiagent decision-making
#
# IV. Key Players in Multiagent Intelligence
# A. Researchers:
# 	* Jason Mathewson (University of Pennsylvania)
# 	* Peter Stone (University of Texas at Austin)
# 	* Eric Horvitz (Microsoft Research)
# B. Organizations:
# 	* MIT CSAIL's Multiagent Systems Group
# 	* University of Edinburgh's Intelligent Systems Laboratory
#
# V. Noteworthy News and Developments
# A. Recent breakthroughs in multiagent reinforcement learning
# B. Advances in explainable AI for multiagent systems
# C. Applications of multiagent intelligence in industries such as healthcare and finance
#
# VI. Content Outline
# I. Introduction
# II. The Basics of Multiagent Intelligence
# III. Trends and Applications
# IV. Key Players and Organizations
# V. Noteworthy News and Developments
# VI. Conclusion
# VII. Call to Action: Getting Started with Multiagent Intelligence Research
#
# VIII. SEO Keywords
# A. Multiagent intelligence
# B. Artificial intelligence (AI)
# C. Machine learning (ML)
# D. Cooperative problem-solving
# E. Explainable AI (XAI)
#
# IX. Resources
# A. Books:
# 	* "Multiagent Systems" by Eric Horvitz and Michael Wellman
# 	* "Artificial Intelligence: A Modern Approach" by Stuart Russell and Peter Norvig
# B. Research papers:
# 	* "Deep Reinforcement Learning with Double Q-Learning" (Arabsat et al., 2020)
# 	* "Explaining Multiagent Systems using Explanable AI" (Lee et al., 2019)
#
# X. Conclusion
#
# Note: This content plan is a comprehensive guide to creating a blog article on multiagent intelligence. The outline, audience analysis, SEO keywords, and resources provided will help ensure that the final article is informative, engaging, and optimized for search engines.
#
# Resources:
# 1.https://www.nature.com/articles/s41595-019-4649-y
# 2.http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.732.2245&rep=rep1&type=pdf
# 3.http://ai.stanford.edu/~amirreza/ams.pdf
