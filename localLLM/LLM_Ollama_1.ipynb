# %%
# install the necessary libraries
#!pip install crewai crewai_tools openai requests litellm

# %%
# Warning control
import warnings
from IPython.display import display
import textwrap
warnings.filterwarnings('ignore')

# %%
import requests
# from crewai.tools import tool

OLLAMA_URL = "http://localhost:11434/api/generate"

# @tool("ollama_llm")
def ollama_llm(prompt: str, model: str = "mistral") -> str:
    """
    Call a local Ollama model and return generated text.
    """
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(OLLAMA_URL, json=payload, timeout=120)
    response.raise_for_status()
    return response.json()["response"]

# %%
print(textwrap.fill(ollama_llm("What is CrewAI? Multiagent framework for LLM"),width=60))
# Out:
#  CrewAI is an open-source multiagent framework designed to
# enable researchers and developers to easily build, train,
# test, and deploy intelligent agents that can collaborate and
# compete with each other in various environments. The main
# focus of the CrewAI platform is to support large-scale
# experiments involving many interacting agents, making it
# suitable for research in areas like multiagent learning,
# cooperative AI, and artificial intelligence for games.  In
# the context of a language model (LLM), CrewAI can
# potentially be used as a platform to train and test agents
# that can engage in natural language conversations with each
# other, simulating human-like interactions. However, it's
# essential to note that currently, CrewAI is not specifically
# designed for language models like me. The focus of CrewAI
# lies mainly in creating multiagent environments and training
# agents within those environments for a wide range of tasks,
# including but not limited to games, robotics, and
# simulation-based problems.  For language model applications,
# other frameworks may be more suitable, such as the Hugging
# Face Transformers library, which is widely used for
# developing and fine-tuning large pretrained models like me.

# %%
from crewai import Agent

ollama_agent = Agent(
    role="AI Research Assistant",
    goal="Answer technical questions using a local LLM",
    backstory="You are a senior AI researcher with deep ML systems knowledge.",
    llm="ollama/llama3.2",        
    verbose=True
)

# %%
display(ollama_agent.kickoff("What is CrewAI?"))
# Out:
# ╭─────────────────────────────────────────────── LiteAgent Started ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LiteAgent Session Started                                                                                      │
# │  Name: AI Research Assistant                                                                                    │
# │  id: 9063fbac-5536-4832-ad37-b52646861770                                                                       │
# │  role: AI Research Assistant                                                                                    │
# │  goal: Answer technical questions using a local LLM                                                             │
# │  backstory: You are a senior AI researcher with deep ML systems knowledge.                                      │
# │  tools: []                                                                                                      │
# │  verbose: True                                                                                                  │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# LiteAgentOutput(raw='CrewAI is an AI-powered platform that uses machine learning and natural language processing to automate various tasks in the film and television industry, particularly in post-production. It helps editors, producers, and directors streamline their workflows by automating tasks such as color correction, visual effects, sound design, and more. The platform uses deep learning algorithms to analyze video footage and provide recommendations for enhancements, allowing creators to achieve a consistent look and feel across multiple projects. CrewAI aims to improve efficiency, reduce costs, and enhance the overall quality of content creation in the film and TV industry.', pydantic=None, agent_role='AI Research Assistant', usage_metrics={'total_tokens': 0, 'prompt_tokens': 0, 'cached_prompt_tokens': 0, 'completion_tokens': 0, 'successful_requests': 0}, messages=[{'role': 'system', 'content': 'You are AI Research Assistant. You are a senior AI researcher with deep ML systems knowledge.\nYour personal goal is: Answer technical questions using a local LLM\n\nTo give my best complete final answer to the task respond using the exact following format:\n\nThought: I now can give a great answer\nFinal Answer: Your final answer must be the great and the most complete as possible, it must be outcome described.\n\nI MUST use these formats, my job depends on it!'}, {'role': 'user', 'content': 'What is CrewAI?'}, {'role': 'assistant', 'content': 'Thought: I can access knowledge about CrewAI using our local LLM.\nFinal Answer: CrewAI is an AI-powered platform that uses machine learning and natural language processing to automate various tasks in the film and television industry, particularly in post-production. It helps editors, producers, and directors streamline their workflows by automating tasks such as color correction, visual effects, sound design, and more. The platform uses deep learning algorithms to analyze video footage and provide recommendations for enhancements, allowing creators to achieve a consistent look and feel across multiple projects. CrewAI aims to improve efficiency, reduce costs, and enhance the overall quality of content creation in the film and TV industry.'}])

# %%
from crewai import Task

task = Task(
    description="Explain the DNN models suitable for the crewai framework.",
    expected_output="A concise technical explanation.",
    agent=ollama_agent
)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
from crewai import Crew

crew = Crew(
    agents=[ollama_agent],
    tasks=[task],
    verbose=True
)

result = crew.kickoff()
print("\nFinal Output:\n", result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 673b16f6-49a0-48cb-97bc-cab94f6cfbe7                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Research Assistant                                                                                   │
# │                                                                                                                 │
# │  Task: Explain the DNN models suitable for the crewai framework.                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: AI Research Assistant                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  The crewai framework primarily supports two types of Deep Neural Network (DNN) models: Convolutional Neural    │
# │  Networks (CNNs) and Recurrent Neural Networks (RNNs).                                                          │
# │                                                                                                                 │
# │  Here's an in-depth explanation of both DNN architectures suitable for the crewai framework:                    │
# │                                                                                                                 │
# │  1. **Convolutional Neural Networks (CNNs):** CNNs are ideal for image classification tasks, which is a common  │
# │  application of the crewai framework. These networks employ convolutional layers followed by pooling layers     │
# │  and fully connected layers to analyze and learn features from images.                                          │
# │                                                                                                                 │
# │     - Convolutional Layers: Enable feature extraction through parallel, local connections.                      │
# │     - Pooling Layers: Downsample the image to reduce spatial dimensions while retaining important information.  │
# │     - Fully Connected Layers: Transform feature maps into probabilities for class labels.                       │
# │                                                                                                                 │
# │  2. **Recurrent Neural Networks (RNNs):** RNNs are well-suited for sequential data such as time series,         │
# │  speech, or text. They work by iteratively processing a sequence of input elements and generating an output     │
# │  that depends on the previous inputs in the sequence.                                                           │
# │                                                                                                                 │
# │     - Long Short-Term Memory (LSTM) Networks: Most commonly used type of RNN, they can "remember" long-term     │
# │  dependencies through gates.                                                                                    │
# │     - Recurrent Layers: Each neuron receives input from all previous time steps.                                │
# │                                                                                                                 │
# │  While other architectures like Autoencoders and Generative Adversarial Networks (GANs) might also be suitable  │
# │  for specific tasks within the crewai framework depending on the nature of the data, CNNs and RNNs are the      │
# │  primary DNN models that it is optimized to handle.                                                             │
# │                                                                                                                 │
# │  In conclusion, CNNs are ideal for image classification due to their ability to extract spatial features        │
# │  effectively. Similarly, RNNs excel at handling sequential data by utilizing the past context in predicting     │
# │  future outcomes or values in a sequence.                                                                       │
# │                                                                                                                 │
# │  Both architectures play crucial roles within the crewai framework and offer robust functionalities for image   │
# │  classification and processing of sequential data depending upon the specific use case.                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
